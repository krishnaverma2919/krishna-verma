# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
driver = webdriver.Chrome()
driver.get("https://www.instahyre.com/python-jobs")
time.sleep(5)
x_path_next_page = '//*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[21]/li[12]'
x_path_job_title = '//*[@id="employer-profile-opportunity"]/div[1]/div'
x_path_location = '//*[@id="employer-profile-opportunity"]/div[2]/span/span'
x_path_founded = '//*[@id="employer-profile-opportunity"]/div[3]/span[1]/span'
x_path_employess ='//*[@id="employer-profile-opportunity"]/div[3]/span[3]/span'
x_path_skill ='//*[@id="employer-profile-opportunity"]/div[5]/ul'
x_path_discription='//*[@id="employer-profile-opportunity"]/div[4]'
idx1 = 1
idx2 = 1
idx3 = 1
idx4 = 1
idx5 = 1
idx6 = 1
title_arr = []
location_arr = []
founded_year_arr = []
employees_arr = []
skills_arr = []
description_arr = []

for i in range(15):
    if idx1!=idx2 or idx2!=idx3 or idx3!=idx4 or idx4!=idx5 or idx5!=idx6:
        print(i)
        break
    elements_job_title = driver.find_elements(by=By.XPATH, value = x_path_job_title)
    for ele in elements_job_title[::2]:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        title_arr.append(temp)
        print(f'{idx1}. ', temp)
        idx1 +=1
    print()

    element_founded= driver.find_elements(by=By.XPATH, value = x_path_founded)
    
    for ele in element_founded[1::2]:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        location_arr.append(temp)
        print(f'{idx2}. ', temp.strip())
        idx2 +=1
    print()
    
    for ele in element_founded[::2]:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        founded_year_arr.append(temp)
        print(f'{idx3}. ', temp)
        idx3 +=1
    print()
    element_employess = driver.find_elements(by=By.XPATH, value = x_path_employess)
    for ele in element_employess:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        employees_arr.append(temp)
        print(f'{idx4}. ', temp)
        idx4 +=1
    print()
    element_skill= driver.find_elements(by=By.XPATH, value = x_path_skill) 
    for ele in element_skill:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        skills_arr.append(temp)
        print(f'{idx5}. ', temp)
        idx5 +=1
    print()
    element_discription= driver.find_elements(by=By.XPATH, value = x_path_discription)
    for ele in element_discription:
        temp = ele.get_attribute('innerHTML')
        temp = temp.strip()
        description_arr.append(temp)
        print(f'{idx6}. ', temp)
        idx6 +=1
    print()
    element_next_page = driver.find_element(by=By.XPATH, value = x_path_next_page)
    element_next_page.click()
    time.sleep(5)            

driver.close()

d = {
    "Job title": title_arr,
    "Location": location_arr,
    "Founded Year": founded_year_arr,
    "No of Employees": employees_arr,
    "Skills": skills_arr,
    "About": description_arr
}
# Out:
# 1.  AI Palette - Senior Full Stack Developer
# 2.  CRED - Product Analyst
# 3.  Deliveroo - Senior Software Engineer
# 4.  Delta Options - Python Developer
# 5.  Idexcel - Data Engineer
# 6.  IGS - SDET
# 7.  Jupiter - Risk Analyst
# 8.  Motherson Group - Site Reliability Engineer
# 9.  Motherson Group - Software Delivery Engineer
# 10.  Motherson Group - System Engineer
# 11.  MSD Technologies - Software Developer
# 12.  NoBroker - Senior Software Engineer - Backend Java Python
# 13.  PubMatic - SDET
# 14.  Pure Storage - SDET
# 15.  ResMed - Senior Data Engineer
# 16.  Synechron - Java - React Developer
# 17.  Synechron - Python - ML Developer
# 18.  Tekion - Senior Data Scientist
# 19.  Walmart Global Tech India - Quality Engineer II - SDET
# 20.  WeWork - Software Developer 2
#
# 1.  Bangalore
# 2.  Bangalore
# 3.  Hyderabad
# 4.  Noida
# 5.  Bangalore
# 6.  Bangalore
# 7.  Bangalore
# 8.  Bangalore
# 9.  Bangalore
# 10.  Bangalore
# 11.  Bangalore
# 12.  Bangalore
# 13.  Pune
# ...

# %%
for i in d.values():
    print(len(i))

# %%
df = pd.DataFrame(d)

# %%
df.head()

# %%
def temp(val):
    return val[-4:]

# %%
df['Founded Year'] = df['Founded Year'].map(temp)

# %%
df.head()

# %%
x = df['Skills'].iloc[0]
x

# %%
def temp(val):
    x = []
    for i in val.split("</li>"):
        idx = i.find('">')
        if idx == -1:
            continue
        x.append(i[idx+2:])
    return ", ".join(x)

# %%
df['Skills'] = df['Skills'].map(temp)

# %%
df.head()

# %%
for i in x.split("</li>"):
    #print(i)
    idx = i.find('">')
    if idx == -1:
        continue             
    print(i[idx+2:])

# %%
#//*[@id="employer-profile-opportunity"]/div[1]/div
#//*[@id="employer-profile-opportunity"]/div[1]/div
#//*[@id="employer-profile-opportunity"]/div[1]/div

#//*[@id="employer-profile-opportunity"]/div[1]/div

#//*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[21]/li[12]
#//*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[21]/li[12]

# %%
temp = "ng-binding ng-scope"
x.count(temp)

# %%
#//*[@id="employer-profile-opportunity"]/div[4]
#//*[@id="employer-profile-opportunity"]/div[4]

# %%
#//*[@id="job-skills-290060"]
#//*[@id="job-skills-289993"]
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a #xpath employer-profile-opportunity
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a/div[5]/ul # full x path skills\
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a/div[5]/ul/li[1]
#//*[@id="employer-profile-opportunity"]/div[5]/ul

# %%
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a/div[1]/div
#/html/body/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/a
#//*[@id="employer-profile-opportunity"]/div[1]/div

# %%
#//*[@id="employer-profile-opportunity"]/div[2]/span/span
#//*[@id="employer-profile-opportunity"]/div[2]/span/span
#//*[@id="employer-profile-opportunity"]/div[3]/span[3]/span

# %%
#//*[@id="employer-profile-opportunity"]/div[3]/span[3]/span

# %%
#//*[@id="employer-profile-opportunity"]/div[3]/span[1]/span
#//*[@id="employer-profile-opportunity"]/div[3]/span[1]/span

# %%
#//*[@id="employer-profile-opportunity"]/div[3]/span[3]/span
#//*[@id="employer-profile-opportunity"]/div[3]/span[3]/span

# %%
x = ''' <!-- ngIf: isSkillsOverflow[opp.job.id] -->
                                <!-- ngRepeat: keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index --><li ng-class="{'special': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index" class="ng-binding ng-scope special">Python</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index --><li ng-class="{'special': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index" class="ng-binding ng-scope">Machine Learning</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index --><li ng-class="{'special': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index" class="ng-binding ng-scope">NLP</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: '-searchedSkill' track by $index -->'''

# %%
temp = "ng-binding ng-scope special"
x.count(temp)

# %%
index=x.find('python')
print(index)

# %%
index=x.find(">Python<")
print(index)

# %%
print(y[38:])

# %%
print(y[-4:])

# %%
print(y[:4:])

# %%
x=orderBy: \'-searchedSkill\' track by $index --><li ng-class="{\'special\': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index" class="ng-binding ng-scope special">Python</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index --><li ng-class="{\'special\': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index" class="ng-binding ng-scope">Machine Learning</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index --><li ng-class="{\'special\': keyword.searchedSkill}" ng-repeat="keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index" class="ng-binding ng-scope">NLP</li><!-- end ngRepeat: keyword in opp.job.keywordOptions | orderBy: \'-searchedSkill\' track by $index -->'

index=x.find(">Python<")
print(index)

# %%
index=x.find(">Python<")
print(index)
